# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C://Users//DELL//Desktop//Covid//Tests_conducted_07April2020.csv')

# %%
data
# Out:
#                 Country or region     Tests  Positive   As of  Tests/ million  \
# 0                         Albania    2571.0     377.0   6 Apr           898.0
# 1                       Argentina    7385.0    1265.0   3 Apr           164.0
# 2                         Armenia    4666.0     822.0   5 Apr          1581.0
# 3                       Australia  303536.0    5800.0   6 Apr         11950.0
# 4    Australian Capital Territory    5422.0      96.0   6 Apr         12707.0
# ..                            ...       ...       ...     ...             ...
# 120                         Texas   85357.0    7276.0   6 Apr          2944.0
# 121                    Washington   87918.0    7591.0   4 Apr         11546.0
# 122                       Uruguay    1538.0     189.0  24 Mar           443.0
# 123                     Venezuela    1779.0     143.0  31 Mar            62.0
# 124                       Vietnam   94305.0     245.0   6 Apr           980.0
#
# ...

# %%
data.shape
# Out:
# (125, 9)

# %%
data.describe()
# Out:
#               Tests       Positive  Tests/ million  Positive/ thousands
# count  1.240000e+02     124.000000      124.000000           124.000000
# mean   9.375284e+04   10986.201613     7153.870968           104.329839
# std    2.203880e+05   37367.887636     8916.112619           105.027210
# min    3.700000e+01       5.000000       22.000000             2.600000
# 25%    7.378750e+03     447.750000     1249.750000            24.250000
# 50%    3.543750e+04    1340.000000     4693.500000            77.500000
# 75%    8.509975e+04    6568.000000    11078.000000           144.750000
# max    1.961953e+06  363220.000000    75405.000000           543.000000

# %%
data.head()
# Out:
#               Country or region     Tests  Positive  As of  Tests/ million  \
# 0                       Albania    2571.0     377.0  6 Apr           898.0
# 1                     Argentina    7385.0    1265.0  3 Apr           164.0
# 2                       Armenia    4666.0     822.0  5 Apr          1581.0
# 3                     Australia  303536.0    5800.0  6 Apr         11950.0
# 4  Australian Capital Territory    5422.0      96.0  6 Apr         12707.0
#
#    Positive/ thousands            Ref.  \
# 0                147.0   cite_note-78
# 1                171.0   cite_note-79
# 2                176.0   cite_note-80
# 3                 19.0   cite_note-81
# 4                 18.0   cite_note-82
#
#                                             Source_1 Source_2
# 0  https://shendetesia.gov.al/5-prill-2020-inform...
# 1  https://www.argentina.gob.ar/sites/default/fil...
# 2  https://ncdc.am/coronavirus/confirmed-cases-by...
# 3  https://twitter.com/Gajafar/status/12471466608...
# ...

# %%
data.tail()
# Out:
#     Country or region    Tests  Positive   As of  Tests/ million  \
# 120             Texas  85357.0    7276.0   6 Apr          2944.0
# 121        Washington  87918.0    7591.0   4 Apr         11546.0
# 122           Uruguay   1538.0     189.0  24 Mar           443.0
# 123         Venezuela   1779.0     143.0  31 Mar            62.0
# 124           Vietnam  94305.0     245.0   6 Apr           980.0
#
#      Positive/ thousands                           Ref.  \
# 120                 85.0                 cite_note-200
# 121                 86.0                 cite_note-201
# 122                123.0                 cite_note-202
# 123                 80.0   cite_note-203 cite_note-204
# 124                  2.6                 cite_note-205
#
#                                               Source_1  \
# 120  https://txdshs.maps.arcgis.com/apps/opsdashboa...
# 121     https://www.doh.wa.gov/Emergencies/Coronavirus
# 122  https://www.montevideo.com.uy/Noticias/Gobiern...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.scatter(x=data['Tests/ million'],y=data['Positive/ thousands'], c='r')
ax.set_title("Tests to Confirmed Cases per million of population",c="g")
ax.set_xlabel("Tests/ million",c='b')
ax.set_ylabel("Confirmed Cases per million",c='b')
# Out:
# Text(0, 0.5, 'Confirmed Cases per million')

# %%
USA = data[data['Country or region'].str.contains('United States')]
print("Number of cases for United States: ", len(USA))
Italy = data[data['Country or region'].str.contains('Italy')]
print("Number of cases for United States: ", len(Italy))
China = data[data['Country or region'].str.contains('China')]
print("Number of cases for United States: ", len(China))
# Out:
# Number of cases for United States:  1
# Number of cases for United States:  1
# Number of cases for United States:  1

# %%
dropIndex = list(USA.index)
print(dropIndex)
print(dropIndex.extend(list(Italy.index)))
print(dropIndex.extend(list(China.index)))
print(len(dropIndex))
World = data.drop(dropIndex,axis=0)
print(World)

print(World.shape)
# Out:
# [112]
# None
# None
# 3
#                 Country or region     Tests  Positive   As of  Tests/ million  \
# 0                         Albania    2571.0     377.0   6 Apr           898.0
# 1                       Argentina    7385.0    1265.0   3 Apr           164.0
# 2                         Armenia    4666.0     822.0   5 Apr          1581.0
# 3                       Australia  303536.0    5800.0   6 Apr         11950.0
# 4    Australian Capital Territory    5422.0      96.0   6 Apr         12707.0
# ..                            ...       ...       ...     ...             ...
# 120                         Texas   85357.0    7276.0   6 Apr          2944.0
# 121                    Washington   87918.0    7591.0   4 Apr         11546.0
# 122                       Uruguay    1538.0     189.0  24 Mar           443.0
# 123                     Venezuela    1779.0     143.0  31 Mar            62.0
# 124                       Vietnam   94305.0     245.0   6 Apr           980.0
#
# ...

# %%
World
# Out:
#                 Country or region     Tests  Positive   As of  Tests/ million  \
# 0                         Albania    2571.0     377.0   6 Apr           898.0
# 1                       Argentina    7385.0    1265.0   3 Apr           164.0
# 2                         Armenia    4666.0     822.0   5 Apr          1581.0
# 3                       Australia  303536.0    5800.0   6 Apr         11950.0
# 4    Australian Capital Territory    5422.0      96.0   6 Apr         12707.0
# ..                            ...       ...       ...     ...             ...
# 120                         Texas   85357.0    7276.0   6 Apr          2944.0
# 121                    Washington   87918.0    7591.0   4 Apr         11546.0
# 122                       Uruguay    1538.0     189.0  24 Mar           443.0
# 123                     Venezuela    1779.0     143.0  31 Mar            62.0
# 124                       Vietnam   94305.0     245.0   6 Apr           980.0
#
# ...

# %%
World.shape
# Out:
# (122, 9)

# %%
data
# Out:
#                 Country or region     Tests  Positive   As of  Tests/ million  \
# 0                         Albania    2571.0     377.0   6 Apr           898.0
# 1                       Argentina    7385.0    1265.0   3 Apr           164.0
# 2                         Armenia    4666.0     822.0   5 Apr          1581.0
# 3                       Australia  303536.0    5800.0   6 Apr         11950.0
# 4    Australian Capital Territory    5422.0      96.0   6 Apr         12707.0
# ..                            ...       ...       ...     ...             ...
# 120                         Texas   85357.0    7276.0   6 Apr          2944.0
# 121                    Washington   87918.0    7591.0   4 Apr         11546.0
# 122                       Uruguay    1538.0     189.0  24 Mar           443.0
# 123                     Venezuela    1779.0     143.0  31 Mar            62.0
# 124                       Vietnam   94305.0     245.0   6 Apr           980.0
#
# ...

# %%
fig,ax1=plt.subplots(figsize=(12,8))
ax1.scatter(x = USA['Tests/ million'],y = USA['Positive/ thousands'],marker = 'x',c="r")
#fig,italy=plt.subplots(figsize=(12,8))
ax1.scatter(x = Italy['Tests/ million'],y = Italy['Positive/ thousands'],marker = 'o',c="b")
ax1.scatter(x = China['Tests/ million'],y = China['Positive/ thousands'],marker = '^',c="m")
ax1.scatter(x = World['Tests/ million'],y = World['Positive/ thousands'],marker = '*',c="g")
ax1.set_title("Tests to Confirmed Cases per million of population",c="g")
ax1.set_xlabel("Tests/ million",c="b")
ax1.set_ylabel("Confirmed Cases/ million",c="b")
# Out:
# Text(0, 0.5, 'Confirmed Cases/ million')

# %%
data['Tests/Positive'] = data['Tests'] / data['Positive']

# %%
data.sort_values(by=['Tests/Positive'], ascending=False, inplace=True)

# %%
data['Tests/Positive']
# Out:
# 124    384.918367
# 29     252.400000
# 38     240.240240
# 109    214.843750
# 80     184.000000
#           ...
# 117      2.384937
# 118      2.166756
# 54       1.886211
# 89       1.840419
# 37            NaN
# Name: Tests/Positive, Length: 125, dtype: float64

# %%
data
# Out:
#          Country or region     Tests  Positive   As of  Tests/ million  \
# 124                Vietnam   94305.0     245.0   6 Apr           980.0
# 29   Northwest Territories    1262.0       5.0   6 Apr         28104.0
# 38               Guangdong  320000.0    1332.0  20 Feb          3068.0
# 109   United Arab Emirates  220000.0    1024.0   3 Apr         22918.0
# 80                   Nepal    1656.0       9.0   5 Apr            59.0
# ..                     ...       ...       ...     ...             ...
# 117               Michigan   41071.0   17221.0   6 Apr          4099.0
# 118             New Jersey   89032.0   41090.0   6 Apr         10024.0
# 54                 Iceland   27467.0   14562.0   6 Apr         75405.0
# 89             Philippines    5974.0    3246.0   5 Apr            59.0
# 37                   China       NaN       NaN     NaN             NaN
#
#      Positive/ thousands                           Ref.  \
# 124                  2.6                 cite_note-205
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Make a fake dataset:
height = data['Tests/Positive']
bars = (data['Country or region'])
y_pos = np.arange(len(bars))
plt.rcParams['figure.figsize']=(100,100)

#plt.plot(figsize=(100,100))
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis

SMALL_SIZE = 10
MEDIUM_SIZE = 20
BIGGER_SIZE = 5

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.xticks(y_pos, bars)
# Show graphic
plt.show()

# %%
data[data['Country or region'].str.contains('India')]
# Out:
#    Country or region     Tests  Positive  As of  Tests/ million  \
# 55             India  101068.0    4135.0  6 Apr            75.0
#
#     Positive/ thousands             Ref.  \
# 55                 41.0   cite_note-135
#
#                                              Source_1 Source_2  Tests/Positive
# 55  https://icmr.nic.in/sites/default/files/whats_...                 24.44208
